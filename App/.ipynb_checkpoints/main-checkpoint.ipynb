# %% [markdown]
# # From the address to the 3D

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

import geopy as gp
import folium

import fiona

from shapely.geometry import Point, Polygon

import rasterio as rio
from rasterio.plot import show
from rasterio.windows import Window

import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

import open3d as o3d

# %%
from functions import *
from raster2xyz import raster2xyz

# %% [markdown]
# ## Enter an address, get a location

# %%
# Google API

country_code = -1

while country_code != 'BE':
    address = input("Please, enter an address in Begium:\n")

    locator = gp.geocoders.GoogleV3(api_key='')
    location = locator.geocode(address, timeout=10)

    postcode = int(location.raw['address_components'][-1]['long_name'])
    country_code = location.raw['address_components'][-2]['short_name']
    coord = (location.latitude, location.longitude)

print("Latitude = {}, Longitude = {}, Postcode = {}".format(coord[1], coord[0], postcode))
# Out:
# Please, enter an address in Begium:
# collegiale sainte waudru
# Latitude = 3.9477585, Longitude = 50.45345440000001, Postcode = 7000

# %% [markdown]
# #### OpenStreet Map (gratuit, moins efficace)
#
# country_code = -1
#
# while country_code != 'be':
#     address = input("Please, enter an address in Begium:\n")
#
#     locator = gp.Nominatim(user_agent="myGeocoder")
#     location = locator.geocode(address, addressdetails=True)
#
#     postcode = int(location.raw['address']['postcode'])
#     country_code = location.raw['address']['country_code']
#     coord = (location.latitude, location.longitude)
#
# print("Latitude = {}, Longitude = {}, Postcode = {}".format(coord[0], coord[1], postcode))

# %%
mappy = folium.Map(
    location=[coord[0],coord[1]],
    zoom_start=17
)

folium.CircleMarker(
    location=[coord[0],coord[1]],
    radius=30,
    popup='Your address',
    color='#3186cc',
    fill=True,
    fill_color='#3186cc'
).add_to(mappy)

mappy
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## From coordinates to correct crs

# %%
p = gpd.GeoSeries([Point(coord[1], coord[0])])
p.crs = 'epsg:4326'
p = p.to_crs(epsg=31370)
print(p[0])

x = p[0].x
y = p[0].y
# Out:
# POINT (120103.7281311091 127041.1390425703)

# %% [markdown]
# ## Get Polygons of houses and terrain coordinates

# %%
properties_src = fiona.open("/home/demes/Documents/Ressources/Cadastre/Bpn_CaPa_WAL.shp", "r")

# %%
shape_property = []
for elem in properties_src :
    if Polygon(elem["geometry"]['coordinates'][0]).contains(p[0]):
        shape_property = [elem["geometry"]]
        property_area = elem['properties']['Shape_area']
        break

# %%
print(f"Area = {property_area} \nShape = {shape_property}")
# Out:
# Area = 5870.0022
# Shape = [{'type': 'Polygon', 'coordinates': [[(120032.11867104332, 127054.77901388519), (120036.72466980049, 127063.64001194946), (120033.2876672292, 127065.70603422076), (120046.23963683636, 127088.74401202891), (120049.62267287017, 127086.96909774095), (120053.98070874451, 127094.46701763012), (120095.34766807297, 127071.61004647892), (120092.06671159873, 127067.22901500016), (120093.38764391966, 127066.50505314488), (120093.75862238556, 127067.13301219419), (120094.85266406149, 127066.51407803502), (120094.53368415083, 127065.86801267229), (120098.12067994935, 127063.72807222418), (120098.4196536052, 127064.32303970028), (120099.52970885717, 127063.81810425222), (120099.24563104333, 127063.18603479024), (120103.29070957209, 127060.84803853184), (120104.70871992383, 127063.3370824689), (120113.3946757956, 127058.58501836285), (120116.13067875421, 127059.15909436997), (120117.06663289777, 127058.66407980677), (120116.69962983171, 127057.82601916604), (120117.32067069414, 127056.40003722906), (120125.85664204026, 127051.79709200282), (120126.49169185905, 127053.00402258337), (120128.2807100821, 127052.10810389649), (120128.90971020647, 127050.33401916362), (120128.6066785915, 127050.09805412032), (120127.65864142265, 127048.18105713464), (120130.68569295263, 127046.57908667903), (120130.9026591042, 127047.11906364653), (120131.78162211023, 127046.70605635736), (120131.43564302113, 127046.07009429671), (120135.63471608759, 127043.66907946952), (120135.99569138556, 127044.27103955578), (120136.72065965927, 127043.92005101219), (120136.4416747567, 127043.22708064131), (120140.8056282539, 127040.64104514476), (120141.18271703194, 127041.35610390548), (120141.85967985852, 127040.96402088739), (120141.5406997058, 127040.31605554), (120145.91965808434, 127037.77001849748), (120146.46164466505, 127038.44805734605), (120147.12870443662, 127038.03107538354), (120146.41271190974, 127036.46905259602), (120147.4246984539, 127036.242030425), (120147.63667170357, 127036.84300831053), (120148.37766222625, 127036.68001886923), (120148.34563032445, 127035.55901669897), (120149.85565098289, 127034.71503170021), (120150.58162423914, 127035.25904784258), (120151.12168822603, 127034.89208133053), (120150.82271465648, 127034.29801388644), (120151.463717856, 127032.54902791698), (120152.27765671539, 127032.79003192391), (120152.29564047934, 127031.79702446423), (120153.7246708711, 127031.04504964873), (120153.9776217838, 127031.45102159027), (120154.79966749763, 127030.89702038094), (120154.50568661737, 127030.24005200248), (120155.23464279665, 127028.93305789214), (120156.11464099289, 127028.82005212177), (120156.37067969021, 127028.26901857462), (120155.8027191912, 127026.11107492168), (120156.39769186184, 127025.81210221723), (120156.00667217244, 127024.83504372649), (120156.83263207493, 127023.54903814662), (120157.56264567349, 127023.58405109495), (120157.67066509256, 127022.88503444847), (120156.9556299826, 127022.66501872521), (120156.65967407369, 127020.51604261156), (120157.55463304992, 127020.06703326106), (120157.32662898171, 127019.2050559055), (120156.52562817637, 127019.28705206327), (120155.8887050616, 127018.30802294612), (120155.54367601691, 127017.24605850223), (120155.68267924635, 127015.5530328434), (120156.21165786003, 127015.31206834316), (120155.83065870992, 127014.50900958013), (120155.2346860394, 127014.80808239523), (120154.12071609325, 127012.63010386191), (120154.75866643945, 127012.13602499198), (120154.12966185718, 127011.31409575883), (120153.31271773958, 127011.88109640963), (120151.63071400118, 127011.18309366237), (120151.7416911165, 127010.123074729), (120151.08371704441, 127010.41705492418), (120150.65470773725, 127008.6800968945), (120151.18966167174, 127008.22803055588), (120150.51966195423, 127007.45210646), (120149.7736873271, 127007.75109719299), (120148.04064176341, 127006.70209865179), (120148.2136902862, 127006.2440755209), (120147.0516317777, 127005.87401239201), (120146.81669933596, 127006.47604368161), ( ...

# %% [markdown]
# buildings_src = fiona.open("/home/demes/Documents/Ressources/Cadastre/Bpn_CaBu.shp", "r")

# %% [markdown]
# shape_buildings = [(elem["geometry"], elem['properties']['Shape_area'])
#                    for elem in buildings_src
#                    if Polygon(shape_property[0]['coordinates'][0]).contains(
#                        Point(elem["geometry"]['coordinates'][0][0]))]

# %% [markdown]
# for building in shape_buildings :
#     print(f"Area = {building[1]} \nShape = {building[0]}")

# %% [markdown]
# ## Get the corrects LiDAR files' path

# %%
path_dsm = ""
path_dtm = ""
flanders = False

if postcode >= 1300 and postcode < 1500:
    path_dsm = set_path_dsm('BRABANT_WALLON')
    path_dtm = set_path_dtm('BRABANT_WALLON')
    print('Walloon Brabant')
    
elif postcode >= 4000 and postcode < 5000:
    path_dsm = set_path_dsm('LIEGE')
    path_dtm = set_path_dtm('LIEGE')
    print('Liège')
    
elif postcode >= 5000 and postcode < 6000:
    path_dsm = set_path_dsm('NAMUR')
    path_dtm = set_path_dtm('NAMUR')
    print('Namur')
    
elif (postcode >= 6000 and postcode < 6600) or (postcode >= 7000 and postcode < 8000):
    path_dsm = set_path_dsm('HAINAUT')
    path_dtm = set_path_dtm('HAINAUT')
    print('Hainaut')
    
elif postcode >= 6600 and postcode < 7000:
    path_dsm = set_path_dsm('LUXEMBOURG')
    path_dtm = set_path_dtm('LUXEMBOURG')
    print('Luxembourg')
    
else:
    number = [x for x in range(1, 44)]
    # ouvrir le .shp avc fiona et chercher le point (A FAIRE)
    for i in number :
        path_dsm = f'/home/demes/Documents/Resources/Flandre/DSM/DHMVIIDSMRAS1m_k{i:02}/GeoTIFF/DHMVIIDSMRAS1m_k{i:02}.tif'
        with rio.open(path_dsm) as dsm:
            #coordinates = (
             #   (x+100, y+100), (x-100, y-100)
            #)
            coordinates = (
                (p[0].x, p[0].y),
            )
            for i, (lon, lat) in enumerate(coordinates):
                # Get pixel coordinates from map coordinates
                print(lon, lat)
                py, px = dsm.index(lon, lat)
                print('Pixel Y, X coords: {}, {}'.format(py, px))

                # Build an NxN window
                small_dsm = dsm.read(1, window=Window(px - N//2, py - N//2, N, N), masked=True)
    flanders = True
    print('Brussels or Flanders region')
# Out:
# Hainaut

# %% [markdown]
# ## Get a sample of the LiDARs, center on the coordinates

# %% [markdown]
# [Highlight on "no value's data"](https://github.com/Demesmaeker/3D_Houses/blob/main/App/highlight_on_no_values_data.ipynb)

# %% [markdown]
# ##### DSM

# %%
coordinates = (
    (p[0].x, p[0].y),
)

# Window's size
N = 300

print(path_dsm)

with rio.open(path_dsm) as dsm:
    for i, (lon, lat) in enumerate(coordinates):
        # Get pixel coordinates from map coordinates
        py, px = dsm.index(lon, lat)
        print('Pixel Y, X coords: {}, {}'.format(py, px))
        
        # Build an NxN window
        small_dsm = dsm.read(1, window=Window(px - N//2, py - N//2, N, N), masked=True)
        dsm_meta = dsm.profile

plt.figure(figsize=(10, 8))
plt.imshow(small_dsm)
plt.colorbar()
plt.show()
# Out:
# /home/demes/Documents/Ressources/Wallonia/DSM 2013-2014/RELIEF_WALLONIE_MNS_2013_2014_GEOTIFF_31370_PROV_HAINAUT/RELIEF_WALLONIE_MNS_2013_2014.tif
# Pixel Y, X coords: 40958, 78103

# %% [markdown]
# ##### DTM

# %%
with rio.open(path_dtm) as dtm:
    for i, (lon, lat) in enumerate(coordinates):
        # Get pixel coordinates from map coordinates
        py, px = dtm.index(lon, lat)
        print('Pixel Y, X coords: {}, {}'.format(py, px))
        
        # Build an NxN window
        small_dtm = dtm.read(1, window=Window(px - N//2, py - N//2, N, N), masked=True)
        dtm_meta = dtm.profile

plt.figure(figsize=(10, 8))
plt.imshow(small_dtm)
plt.colorbar()
plt.show()
# Out:
# Pixel Y, X coords: 40958, 78103

# %% [markdown]
# ## Canopy Height Model

# %% [markdown]
# [Highlight on Canopy Height Model and Hillshade](https://github.com/Demesmaeker/3D_Houses/blob/main/App/Highlight%20on%20the%20Canopy%20Height%20Model%20and%20Hillshade.ipynb)

# %% [markdown]
# ## Transform raster into xyz dataframes

# %%
shape = [{'type': 'Polygon', 
          'coordinates': [[(x+75, y+75), 
                           (x-75, y+75), 
                           (x-75, y-75), 
                           (x+75, y-75)]]}]

# %%
# shape_property

# %% [markdown]
# buildings = []
# for building in shape_buildings :
#     buildings += building[0]

# %% [markdown]
# Get the xyz coordinates of the points

# %%
base_dsm = raster2xyz.translate_from_cropped(get_mask(path_dsm, shape))
base_dtm = raster2xyz.translate_from_cropped(get_mask(path_dtm, shape))
property_dsm = raster2xyz.translate_from_cropped(get_mask(path_dsm, shape_property))
property_dtm = raster2xyz.translate_from_cropped(get_mask(path_dtm, shape_property))

# %% [markdown]
# Get some dataframes

# %%
df_base_dsm = get_dataframe(base_dsm)
df_base_dtm = get_dataframe(base_dtm)
df_base_chm = get_chm_df(df_base_dsm, df_base_dtm)

df_property_dsm = get_dataframe(property_dsm)
df_property_dtm = get_dataframe(property_dtm)
df_property_chm = get_chm_df(df_property_dsm, df_property_dtm)

# %%
df_base_dsm.describe()
# Out:
#                    x              y             z
# count   22801.000000   22801.000000  22801.000000
# mean   127192.000000  120103.000000     58.836514
# std        43.589945      43.589945     10.392298
# min    127117.000000  120028.000000     43.620853
# 25%    127154.000000  120065.000000     51.070000
# 50%    127192.000000  120103.000000     56.759998
# 75%    127230.000000  120141.000000     64.410004
# max    127267.000000  120178.000000     92.739998

# %%
df_base_dsm
# Out:
#               x         y          z
# 0      127117.0  120028.0  52.799999
# 1      127118.0  120028.0  52.750000
# 2      127119.0  120028.0  51.869999
# 3      127120.0  120028.0  51.900002
# 4      127121.0  120028.0  45.110001
# ...         ...       ...        ...
# 22796  127263.0  120178.0  52.209999
# 22797  127264.0  120178.0  52.240002
# 22798  127265.0  120178.0  52.240002
# 22799  127266.0  120178.0  52.290001
# 22800  127267.0  120178.0  56.877628
#
# [22801 rows x 3 columns]

# %% [markdown]
# ## Convert the datasets to 3D

# %% [markdown]
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
#
# X = df_property_dsm['x']
# Y = df_property_dsm['y']
# Z = df_property_dsm['z']
#
# ax.scatter(X, Y, Z, c='r', marker='o')
#
# ax.set_xlabel('x axis')
# ax.set_ylabel('y axis')
# ax.set_zlabel('z axis')
#
# plt.show()

# %% [markdown]
# ### Points cloud

# %% [markdown]
# ##### DSM

# %%
show_pcd(df_base_dsm)

# %%
show_pcd(df_property_dsm)

# %% [markdown]
# ##### DTM

# %%
show_pcd(df_base_dtm)

# %%
show_pcd(df_property_dtm)

# %% [markdown]
# ##### CHM

# %%
show_pcd(df_base_chm)

# %%
show_pcd(df_property_chm)

# %% [markdown]
# ### 3D

# %% [raw]
# Reconstruction using Poisson

# %%
show_poisson(df_base_dsm)
# Out:
# [Open3D DEBUG] Input Points / Samples: 22801 / 22801
# [Open3D DEBUG] #   Got kernel density: 0.118917 (s), 362.383 (MB) / 362.383 (MB) / 426 (MB)
# [Open3D DEBUG] #     Got normal field: 0.069325 (s), 371.391 (MB) / 371.391 (MB) / 426 (MB)
# [Open3D DEBUG] Point weight / Estimated Area: 1.010883e-04 / 2.304914e+00
# [Open3D DEBUG] #       Finalized tree: 0.14237 (s), 372.68 (MB) / 372.68 (MB) / 426 (MB)
# [Open3D DEBUG] #  Set FEM constraints: 0.403092 (s), 372.68 (MB) / 372.68 (MB) / 426 (MB)
# [Open3D DEBUG] #Set point constraints: 0.03947 (s), 372.68 (MB) / 372.68 (MB) / 426 (MB)
# [Open3D DEBUG] Leaf Nodes / Active Nodes / Ghost Nodes: 954640 / 331512 / 759505
# [Open3D DEBUG] Memory Usage: 372.680 MB
# [Open3D DEBUG] # Linear system solved: 0.523566 (s), 372.68 (MB) / 372.68 (MB) / 426 (MB)
# [Open3D DEBUG] Got average: 0.0235469 (s), 372.68 (MB) / 372.68 (MB) / 426 (MB)
# [Open3D DEBUG] Iso-Value: 4.904551e-01 = 1.118287e+04 / 2.280100e+04
# [Open3D DEBUG] #          Total Solve:       3.2 (s),     383.5 (MB)

# %%
show_poisson(df_property_dsm)
# Out:
# [Open3D DEBUG] Input Points / Samples: 6123 / 6123
# [Open3D DEBUG] #   Got kernel density: 0.045898 (s), 384.289 (MB) / 384.289 (MB) / 426 (MB)
# [Open3D DEBUG] #     Got normal field: 0.019784 (s), 386.094 (MB) / 386.094 (MB) / 426 (MB)
# [Open3D DEBUG] Point weight / Estimated Area: 1.834367e-04 / 1.123183e+00
# [Open3D DEBUG] #       Finalized tree: 0.060158 (s), 386.352 (MB) / 386.352 (MB) / 426 (MB)
# [Open3D DEBUG] #  Set FEM constraints: 0.17032 (s), 386.352 (MB) / 386.352 (MB) / 426 (MB)
# [Open3D DEBUG] #Set point constraints: 0.014545 (s), 386.352 (MB) / 386.352 (MB) / 426 (MB)
# [Open3D DEBUG] Leaf Nodes / Active Nodes / Ghost Nodes: 387710 / 140880 / 302217
# [Open3D DEBUG] Memory Usage: 386.352 MB
# [Open3D DEBUG] # Linear system solved: 0.239551 (s), 386.352 (MB) / 386.352 (MB) / 426 (MB)
# [Open3D DEBUG] Got average: 0.00836301 (s), 386.352 (MB) / 386.352 (MB) / 426 (MB)
# [Open3D DEBUG] Iso-Value: 5.026338e-01 = 3.077626e+03 / 6.123000e+03
# [Open3D DEBUG] #          Total Solve:       2.0 (s),     386.8 (MB)

# %%
show_poisson(df_base_chm)
# Out:
# [Open3D DEBUG] Input Points / Samples: 22801 / 22801
# [Open3D DEBUG] #   Got kernel density: 0.109719 (s), 386.812 (MB) / 386.812 (MB) / 426 (MB)
# [Open3D DEBUG] #     Got normal field: 0.0800939 (s), 386.812 (MB) / 386.812 (MB) / 426 (MB)
# [Open3D DEBUG] Point weight / Estimated Area: 9.994513e-05 / 2.278849e+00
# [Open3D DEBUG] #       Finalized tree: 0.159305 (s), 392.996 (MB) / 392.996 (MB) / 426 (MB)
# [Open3D DEBUG] #  Set FEM constraints: 0.520417 (s), 392.996 (MB) / 392.996 (MB) / 426 (MB)
# [Open3D DEBUG] #Set point constraints: 0.043222 (s), 392.996 (MB) / 392.996 (MB) / 426 (MB)
# [Open3D DEBUG] Leaf Nodes / Active Nodes / Ghost Nodes: 946695 / 358224 / 723713
# [Open3D DEBUG] Memory Usage: 392.996 MB
# [Open3D DEBUG] # Linear system solved: 0.549285 (s), 392.996 (MB) / 392.996 (MB) / 426 (MB)
# [Open3D DEBUG] Got average: 0.0458529 (s), 392.996 (MB) / 392.996 (MB) / 426 (MB)
# [Open3D DEBUG] Iso-Value: 4.857093e-01 = 1.107466e+04 / 2.280100e+04
# [Open3D DEBUG] #          Total Solve:       3.3 (s),     407.2 (MB)

# %%
show_poisson(df_property_chm)
# Out:
# [Open3D DEBUG] Input Points / Samples: 6123 / 6123
# [Open3D DEBUG] #   Got kernel density: 0.041744 (s), 407.238 (MB) / 407.238 (MB) / 426 (MB)
# [Open3D DEBUG] #     Got normal field: 0.0289581 (s), 407.238 (MB) / 407.238 (MB) / 426 (MB)
# [Open3D DEBUG] Point weight / Estimated Area: 1.843432e-04 / 1.128733e+00
# [Open3D DEBUG] #       Finalized tree: 0.0594299 (s), 407.238 (MB) / 407.238 (MB) / 426 (MB)
# [Open3D DEBUG] #  Set FEM constraints: 0.170239 (s), 407.238 (MB) / 407.238 (MB) / 426 (MB)
# [Open3D DEBUG] #Set point constraints: 0.0150259 (s), 407.238 (MB) / 407.238 (MB) / 426 (MB)
# [Open3D DEBUG] Leaf Nodes / Active Nodes / Ghost Nodes: 385911 / 140336 / 300705
# [Open3D DEBUG] Memory Usage: 407.238 MB
# [Open3D DEBUG] # Linear system solved: 0.249568 (s), 407.238 (MB) / 407.238 (MB) / 426 (MB)
# [Open3D DEBUG] Got average: 0.00898099 (s), 407.238 (MB) / 407.238 (MB) / 426 (MB)
# [Open3D DEBUG] Iso-Value: 5.040268e-01 = 3.086156e+03 / 6.123000e+03
# [Open3D DEBUG] #          Total Solve:       1.9 (s),     407.5 (MB)
